# %% [markdown]
# # My Jupyter Notebook on Watson Studio

# %% [markdown]
# # I am Gaurav Shrivastava
# # I work as a Project Engineer delivering EPC Contracts for Air Pollution Control Equipments

# %% [markdown]
# *I am interested in data science because it helps me effectively analyze the various risks that are involved in delivering high value projects, I can quantify the numbers using the dynamics and present them more effectively for further project and business related decisions*

# %% [markdown]
# # My code below is going to perform a simple addition

# %%
1+2
# Out:
# 3

# %% [markdown]
# ## Travelling Expenses
# Inline-style:
# ![alt text](https://github.com/adam-p/markdown-here/raw/master/src/common/images/icon48.png "Logo Title Text 1")
#
# | Description   | Currency      | Amount|
# | ------------- |:-------------:| -----:|
# | Flights       |  INR          | 14000 |
# | Lodging       |  INR          |  6000 |
# | Claimed Amount|  INR          | 20000 |
